# %%
import pandas as pd

data = pd.read_hdf(r"D:\Dropbox (UCL)\Rotation_vte\Locomotion\analysis\ephys\GLM\data\FC_220408_BAA1101192_hairpin_bouts.h5", key="data")
data.head()
# Out:
#            s         sdot          v   dv_250ms  dv_500ms  dv_1000ms  \
# 0  39.952896  2397.173780  11.124197  11.037970  4.134042   0.989485
# 1  40.054041     6.068656  11.569405  10.832615  3.468731   0.477680
# 2  40.155185     6.068656  12.010486  10.617308  2.782386  -0.021065
# 3  40.256329     6.068656  12.451567  10.402000  2.096040  -0.519811
# 4  40.329346     4.381006  12.892648  10.186692  1.409695  -1.018556
#
#         omega  domega_250ms  domega_500ms  domega_1000ms  ...  232_shuffle_90  \
# 0  202.829523   -214.510860   -133.997352    -242.917613  ...        5.810512
# 1  193.162064   -206.980492   -119.232663    -234.075342  ...        6.009282
# 2  185.994086   -200.601354   -107.689036    -230.152733  ...        6.189872
# 3  178.826108   -194.222216    -96.145409    -226.230124  ...        6.348369
# 4  171.658130   -187.843078    -84.601781    -222.307516  ...        6.481597
#
#    232_shuffle_91  232_shuffle_92  232_shuffle_93  232_shuffle_94  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.scatter(np.arange(len(data.s)), data.s, c=data[232])

plt.plot(data[232].values[:10*200])
